# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import gridspec as gs
import matplotlib
import sys; sys.path.append("..")
from BtspStatistics import BtspStatistics
# %matplotlib widget
import warnings
warnings.filterwarnings("ignore")

# %%
area = "CA3"
data_path = r"C:\Users\martin\home\phd\btsp_project\analyses\manual"
output_path = r"C:\Users\martin\home\phd\btsp_project\analyses\manual"
extra_info = "reboot"
is_shift_criterion_on = True
is_notebook = True

stats = BtspStatistics(area, data_path, output_path, extra_info, is_shift_criterion_on, is_notebook)
stats.load_data()
stats.calc_place_field_proportions()
stats.calc_shift_gain_distribution(unit="cm")

# %% [markdown]
# # Behavior

# %% [markdown]
# # Cell counts

# %%
stats.plot_cells()

# %% [markdown]
# # Place field counts and proportions

# %%
stats.plot_place_fields()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
stats.plot_place_fields_by_session()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
stats.plot_place_field_proportions()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
stats.plot_place_fields_criteria_venn_diagram(with_btsp=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Newly formed vs. established analysis

# %%
stats.plot_shift_gain_distribution(without_transient=False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
stats.plot_shift_gain_distribution(without_transient=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Bootstrapping

# %% [markdown]
# ## PCA, factor analysis

# %% [markdown]
# # Place field properties

# %% [markdown]
# ## Width, lifespan, etc.

# %% [markdown]
# ## Reliability

# %% [markdown]
# ## Lap-by-lap analysis

# %% [markdown]
# # BTSP properties

# %% [markdown]
# ## Distribution of signatures

# %% [markdown]
# ## Effect of shift criterion

# %% [markdown]
# # Deep-superficial analysis

# %% [markdown]
# # Controls

# %% [markdown]
# ## Shuffled laps analysis

# %% [markdown]
# ## Reverse analysis
