# %%
from ImageAnal import *
# %matplotlib widget

# %%
datapath = r"C:\\Users\\martin\\home\\makaralab\\ABmice\\"
date_time = '2021-10-31_11-01-07'
animalID = 'KS028'
task = 'NearFarLong'
suite2p_folder = f"{datapath}/data/{animalID}_imaging/KS028_103121/"
TRIGGER_VOLTAGE_FILENAME = f"{suite2p_folder}/KS028_TSeries-10312021-1017-002_Cycle00001_VoltageRecording_001.csv"
imaging_logfile_name = f"{suite2p_folder}/KS028_TSeries-10312021-1017-002.xml"

ISD = ImagingSessionData(datapath, date_time, animalID, task, suite2p_folder, imaging_logfile_name, TRIGGER_VOLTAGE_FILENAME)
# Out:
# trigger logfile loaded
# trigger voltage signal loaded
# deleting first fall
# triggers after: 65
# n_extra_indexes 5
# candidate log indexes [27, 126]
# min recorded trigger length: 0.2815999999999992
# relevant behavior located, lap time of the first frame: 1228.052422 , log reference index: 126
# suite2p data loaded
# corrected offset: 1228.048422 voltage_delay: 0.00399999999990541
# single-plane
# suite2p time axis loaded
# calculating dF/F and SNR...
# SNR done
# dF/F calculated for cell ROI-s
# ExpStateMachineLog time interval > 1s:  1  times
# length of frame_times: 17994
# length of frame_laps: 17994
# shape of dF_F: (463, 17994)
# ...
# Early end lap found, last position: 1420.82 in lap 191 in corridor 15
# Short lap found, we have total  3481 position bins recorded by the ExpStateMachine in a lap before lap 203 in corridor 15
# laps with im data:  [125 126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142
# ...

# %%
ISD.show_behavior_score()
# Out:
# Pcorrect (corr. 14) = 1.00
# Pcorrect (corr. 15) = 1.00
# Norm. speed selectivity (corr. 14) = 0.24
# Norm. speed selectivity (corr. 15) = 0.20
# Norm. speed selectivity (cross-corr) = 0.17
# Lick selectivity (corr. 14) = 0.59
# Lick selectivity (corr. 15) = 0.60
# Lick selectivity (cross-corr) = 0.36
# ----------
# behavior score = 4.17

# %%
ISD.plot_session(selected_laps=ISD.i_Laps_ImData, average=False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ISD.i_Laps_ImData
# Out:
# array([125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137,
#        138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150,
#        151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163,
#        164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176,
#        177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189,
#        190])
